# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_moons,make_circles,make_classification

# X, Y = make_moons(n_samples=2000, noise=0.15, random_state=1)
X, Y = make_circles(n_samples=2000, noise=0.2, random_state=1)

print(X.shape, Y.shape)

(2000, 2)

plt.scatter(X[:,0 ], X[:, 1], c=Y)
plt.show()
# Out:
# (2000, 2) (2000,)

# %%
def load_dataset(dataset):
    if dataset=='moons':
        X, Y = make_moons(n_samples=2000, noise=0.15, random_state=1)
    elif dataset=='circles':
        X, Y = make_circles(n_samples=2000, noise=0.15, random_state=1)
    elif dataset=='classification':
        X, Y = make_classification(n_samples=2000, noise=0.15, random_state=1)
        
        return X,Y

# %%
dataset ='moons'
X,Y =load_dataset(dataset)
print(X.shape, Y.shape)
    
(2000,2) 
plt.scatter(X[:,0], X[:,1],c=Y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 dataset ='moons'
# ----> 2 X,Y =load_dataset(dataset)
#       3 print(X.shape, Y.shape)
#       5 (2000,2)
#
# TypeError: cannot unpack non-iterable NoneType object
